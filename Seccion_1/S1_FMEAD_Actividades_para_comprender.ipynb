# %% [markdown]
# # Actividad para comprender

# %% [markdown]
# ## 1. Funciones y Gráficas en el Plano:
#
# * Elija una función matemática relevante y grafique en el plano cartesiano. Explique cómo la función se relaciona con problemas de ciencia de datos.

# %% [markdown]
# ### Prompt utilizado en GPT para Actividad 1
#
# *Diseña código Python para graficar una función matemática relevante para ciencia de datos y explica cómo se relaciona con problemas de ciencia de datos.*

# %% [markdown]
# ¿Qué prompt podrías utilizar para indicarle al GPT que, modificando el código anterior y dado un valor de `X`, obtenga un valor de probabilidad en `Y`; y, que al mismo tiempo, los muestre con líneas punteadas, tal como se muestra en la imagen inferior?

# %% [markdown]
# ![descarga.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Límite de Funciones y Convergencia
#
# * Seleccione una sucesión de datos y calcule su límite. Utilice métodos computacionales para aproximarse al valor de convergencia. Explique la importancia de entender la convergencia en ciencia de datos.

# %% [markdown]
# ### Sugerencia de uso de GPT para Actividad 2
#
# *Si no entendemos qué nos quiere decir el ejercicio, le podemos decir al GPT que nos lo explique y que nos diseñe código en Python que complemente la explicación.*

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Diferenciación e Integración:
#
# * Trabaje con una función que represente un fenómeno en ciencia de datos. Calcule la derivada e integral de la función y explique su aplicación en problemas del mundo real.

# %% [markdown]
# ### Prompt utilizado en GPT para Actividad 3
#
# *Dame un ejemplo de una función importante que represente un fenómeno en ciencia de datos, calcula tanto la derivada como la integral de la función y explica su aplicación en problemas del mundo real.*
